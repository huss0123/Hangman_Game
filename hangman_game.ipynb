# %%
import random as r

# %%
#list of fruits to choose from
list =["apple", "banana", "grape", "orange", "mango", "kiwi", "strawberry", "watermelon", "peach", "cherry"]
word = r.choice(list)
word_length = len(word)
display = ["-"*word_length]
print("Hello to HANGMAN GAME\nTry to guess the hidden fruit")
print(f"the fruit contains {word_length} letters")
print(display)

for i in range(word_length+2) :
    user_input= input("enter a valid letter")
    if user_input in word:
        print("correct letter")
        w
# Out:
# Hello to HANGMAN GAME
# Try to guess the hidden fruit
# the fruit contains 6 characters
# ['------']

# %%
print(word)
print(word_length)
print(display)
# Out:
# banana
# 6
# ['------']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 print(word_length)
#       3 print(display)
# ----> 5 word.index()
#
# TypeError: index expected at least 1 argument, got 0

# %%
word.index("a")
# Out:
# 1
